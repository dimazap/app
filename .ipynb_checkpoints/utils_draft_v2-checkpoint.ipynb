# %%
from pprint import pprint
import json
import requests

structure = {'slice[]': 'offer', 'filter[advertiser]': '5b2a22d373bdda49008b4604', 'filter[date_to]': '2018-10-02', 'filter[date_from]': '2018-10-01', 'API-key': '37796ce6525a581c56a493ccd39402eadca187de'}

r = requests.get('https://api.dzdata.affise.com/3.0/stats/custom', verify=False, params=structure)

#pprint(r.url)

data = json.loads(r.content)

pprint(data)

#print(type(data['stats']))

elems = data['stats']

#levels = len(elems)

#total_charge = [elems['actions']['total']['charge'] for elems in elems]

#pprint(total_charge)
# Out:
# /Users/dmytro/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# {'pagination': {'page': 1, 'per_page': 100, 'total_count': 85},
#  'stats': [{'actions': {'confirmed': {'charge': 6.4,
#                                       'count': 2,
#                                       'earning': 2.6,
#                                       'null': 0,
#                                       'revenue': 3.8},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 6.4,
#                                   'count': 2,
#                                   'earning': 2.6,
#                                   'null': 0,
#                                   'revenue': 3.8}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '1:65727',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 9413,
#                                 'offer_id': '5bb1f5a4dbb327527d27ab82',
#                                 'title': 'Dlab_FINAL FANTASY BRAVE '
#                                          'EXVIUS_JP_iOS_1805_SM '
#                                          '(flaJdhVSSIK8KlbWHNHWvA) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=flaJdhVSSIK8KlbWHNHWvA&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '131454', 'uniq': '122154'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 81.6,
#                                       'count': 102,
#                                       'earning': 35.7,
#                                       'null': 0,
#                                       'revenue': 45.9},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 81.6,
#                                   'count': 102,
#                                   'earning': 35.7,
#                                   'null': 0,
#                                   'revenue': 45.9}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '1:58468',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 3239,
#                                 'offer_id': '5b90e471dbb3277f0529043e',
#                                 'title': 'Dlab_SSG TV Shopping_KR_And_1805 '
#                                          '(Q5CB_5WERqGsneaLgh9foA) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=Q5CB_5WERqGsneaLgh9foA&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '5963753', 'uniq': '3721396'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 0,
#                                   'count': 0,
#                                   'earning': 0,
#                                   'null': 0,
#                                   'revenue': 0}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 2815,
#                                 'offer_id': '5b8e61b5dbb32755d80a7926',
#                                 'title': 'Dlab_LINE BROWN FARM_JP_And '
#                                          '(zIAm9J4eTcCHIUDyHe2ohw) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=zIAm9J4eTcCHIUDyHe2ohw&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '15963', 'uniq': '13601'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 0,
#                                   'count': 0,
#                                   'earning': 0,
#                                   'null': 0,
#                                   'revenue': 0}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 1715,
#                                 'offer_id': '5b71529c73bdda56008b4a3b',
#                                 'title': 'Yahoo Partner JP iOS (NET-45) PR12',
#                                 'url': 'http://rfrl.pw/xxk?c=hp_SIJxySuivwxHKbQIwyQ&pt=03bVNw6&h1={clickid}&pi={pid}&spi={sub2}&ia={sub4}&aia={sub4}&cn={sub3}'}},
#             'traffic': {'raw': '245375', 'uniq': '237067'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 2.6,
#                                       'count': 1,
#                                       'earning': 1.05,
#                                       'null': 0,
#                                       'revenue': 1.55},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 2.6,
#                                   'count': 1,
#                                   'earning': 1.05,
#                                   'null': 0,
#                                   'revenue': 1.55}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0.0001,
#             'ratio': '1:46334',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 6335,
#                                 'offer_id': '5ba3912cdbb3279464414033',
#                                 'title': 'Dlab_萬王之王_HKMO_And BL '
#                                          '(GchoyDhtSjivgUaophtMuA) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=GchoyDhtSjivgUaophtMuA&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '46334', 'uniq': '24489'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 0,
#                                   'count': 0,
#                                   'earning': 0,
#                                   'null': 0,
#                                   'revenue': 0}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 7126,
#                                 'offer_id': '5ba7d8bbdbb32740f4588c90',
#                                 'title': 'Dlab_烈火如歌_MY_And '
#                                          '(KO7wUhkESkePmMHBcp3m5g) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=KO7wUhkESkePmMHBcp3m5g&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '5495', 'uniq': '5079'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 2.2,
#                                       'count': 1,
#                                       'earning': 0.88,
#                                       'null': 0,
#                                       'revenue': 1.32},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 2.2,
#                                   'count': 1,
#                                   'earning': 0.88,
#                                   'null': 0,
#                                   'revenue': 1.32}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '1:1',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 2445,
#                                 'offer_id': '5b866bc373bdda50008b4f86',
#                                 'title': 'IDOLiSH7 JP Android (NET-45)',
#                                 'url': 'http://rfrl.pw/xxk?c=OHpmjNyqT3qZvCu1uz7VbQ&pt=03bVNw6&h1={clickid}&pi={pid}&spi={sub2}&ia={sub4}&aia={sub4}&cn={sub3}'}},
#             'traffic': {'raw': '0', 'uniq': '0'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 148.5,
#                                       'count': 55,
#                                       'earning': 60.5,
#                                       'null': 0,
#                                       'revenue': 88},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 148.5,
#                                   'count': 55,
#                                   'earning': 60.5,
#                                   'null': 0,
#                                   'revenue': 88}},
#             'cr': {'confirmed': 0.06,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0.06},
#             'ctr': 0,
#             'epc': 0.0015,
#             'ratio': '1:1811',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 2862,
#                                 'offer_id': '5b8e8cf7dbb32758da311ba7',
#                                 'title': 'Dlab_Texas Poker_TW_And (180628 '
#                                          'GreenOpen) (9Uw594AgTPqDvZ8ylhEPpw) '
#                                          '(NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=9Uw594AgTPqDvZ8ylhEPpw&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '99585', 'uniq': '81803'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 0,
#                                   'count': 0,
#                                   'earning': 0,
#                                   'null': 0,
#                                   'revenue': 0}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 5794,
#                                 'offer_id': '5ba1f6ccdbb327758c60ef79',
#                                 'title': 'Dlab_Spotify_JP_And_1805_SM '
#                                          '(LBaseHWNQamIdpHsWIriow) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=LBaseHWNQamIdpHsWIriow&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '24012', 'uniq': '14782'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 77,
#                                       'count': 35,
#                                       'earning': 30.8,
#                                       'null': 0,
#                                       'revenue': 46.2},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 77,
#                                   'count': 35,
#                                   'earning': 30.8,
#                                   'null': 0,
#                                   'revenue': 46.2}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '1:51962',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 2222,
#                                 'offer_id': '5b7e767773bddadf5f8b4578',
#                                 'title': 'Rakuten Ichiba Cyber JP Android '
#                                          '(NET-45)',
#                                 'url': 'http://rfrl.pw/xxk?c=7eoO9lX8SqKh2E_KiUo9gw&pt=03bVNw6&h1={clickid}&pi={pid}&spi={sub2}&ia={sub4}&aia={sub4}&cn={sub3}'}},
#             'traffic': {'raw': '1818656', 'uniq': '789573'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 3.5,
#                                       'count': 1,
#                                       'earning': 1.4,
#                                       'null': 0,
#                                       'revenue': 2.1},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 3.5,
#                                   'count': 1,
#                                   'earning': 1.4,
#                                   'null': 0,
#                                   'revenue': 2.1}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0.0001,
#             'ratio': '1:68709',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 7389,
#                                 'offer_id': '5ba9e4cedbb3270e62339513',
#                                 'title': 'Dlab_En-musubi_JP_iOS_201804_SM '
#                                          '(iOYWwi9LQuC5UTmw1UlNTQ) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=iOYWwi9LQuC5UTmw1UlNTQ&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '68709', 'uniq': '66737'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 70.4,
#                                       'count': 32,
#                                       'earning': 28.8,
#                                       'null': 0,
#                                       'revenue': 41.6},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 70.4,
#                                   'count': 32,
#                                   'earning': 28.8,
#                                   'null': 0,
#                                   'revenue': 41.6}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0.0001,
#             'ratio': '1:27141',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 3421,
#                                 'offer_id': '5b960ebcdbb32750a751e6d3',
#                                 'title': 'Dlab_Live.me_JP_iOS '
#                                          '(LGm901SDTBmDjf-7dSHwrQ) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=LGm901SDTBmDjf-7dSHwrQ&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '868519', 'uniq': '783782'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 0,
#                                   'count': 0,
#                                   'earning': 0,
#                                   'null': 0,
#                                   'revenue': 0}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 3238,
#                                 'offer_id': '5b90e470dbb3277f1111ad60',
#                                 'title': 'Dlab_Tatacliq_IN_And_BL '
#                                          '(MmGENSuRQ4y8MNYhiRkBvQ) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=MmGENSuRQ4y8MNYhiRkBvQ&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '5163', 'uniq': '2584'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 0,
#                                   'count': 0,
#                                   'earning': 0,
#                                   'null': 0,
#                                   'revenue': 0}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 3418,
#                                 'offer_id': '5b95f99fdbb3274c8d1e9dfa',
#                                 'title': 'Dlab_Kotak_CPR_IN_And '
#                                          '(XmSpzNROQxSFfaYt49ZvUw) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=XmSpzNROQxSFfaYt49ZvUw&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '1636', 'uniq': '1164'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 0,
#                                   'count': 0,
#                                   'earning': 0,
#                                   'null': 0,
#                                   'revenue': 0}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 3281,
#                                 'offer_id': '5b9123d5dbb32783cc42c508',
#                                 'title': 'Dlab_Mr. Voonik CPS And_API '
#                                          '(XQl_p49tTo6CZXimUcYlWw) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=XQl_p49tTo6CZXimUcYlWw&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '3219', 'uniq': '1877'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 154,
#                                       'count': 55,
#                                       'earning': 63.25,
#                                       'null': 0,
#                                       'revenue': 90.75},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 154,
#                                   'count': 55,
#                                   'earning': 63.25,
#                                   'null': 0,
#                                   'revenue': 90.75}},
#             'cr': {'confirmed': 1.09,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 1.09},
#             'ctr': 0,
#             'epc': 0.0304,
#             'ratio': '1:92',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 6640,
#                                 'offer_id': '5ba4e4c0dbb32711c10e6f98',
#                                 'title': 'Dlab_仙劍逍遙遊_TW_And_BL '
#                                          '(iIQ_DbOvQXSqofCOzk-u8A) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=iIQ_DbOvQXSqofCOzk-u8A&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '5067', 'uniq': '4639'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 548.6,
#                                       'count': 422,
#                                       'earning': 232.1,
#                                       'null': 0,
#                                       'revenue': 316.5},
#                         'declined': {'charge': 71.5,
#                                      'count': 61,
#                                      'earning': 30.25,
#                                      'null': 6,
#                                      'revenue': 41.25},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 620.1,
#                                   'count': 483,
#                                   'earning': 262.35,
#                                   'null': 6,
#                                   'revenue': 357.75}},
#             'cr': {'confirmed': 0.01,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0.01},
#             'ctr': 0,
#             'epc': 0.0001,
#             'ratio': '1:7893',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 6182,
#                                 'offer_id': '5ba31a17dbb3278b6f715640',
#                                 'title': 'Dlab_Spotify_JP_iOS_1805_SM '
#                                          '(PGAm0IKFSQungcPRpyZOYA) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=PGAm0IKFSQungcPRpyZOYA&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '3812152', 'uniq': '3425861'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 12,
#                                       'count': 10,
#                                       'earning': 5,
#                                       'null': 0,
#                                       'revenue': 7},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 12,
#                                   'count': 10,
#                                   'earning': 5,
#                                   'null': 0,
#                                   'revenue': 7}},
#             'cr': {'confirmed': 0.01,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0.01},
#             'ctr': 0,
#             'epc': 0.0002,
#             'ratio': '1:7592',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 3502,
#                                 'offer_id': '5b97add2dbb3276a571c33cc',
#                                 'title': 'Dlab_Brandi NCPI_KR_1807_iOS '
#                                          '(HxUXtaE7QXO0nmAkeEXQEA) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=HxUXtaE7QXO0nmAkeEXQEA&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '75920', 'uniq': '68850'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 0,
#                                   'count': 0,
#                                   'earning': 0,
#                                   'null': 0,
#                                   'revenue': 0}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 5029,
#                                 'offer_id': '5b9bb760dbb32708962fe011',
#                                 'title': 'Dlab_Pinjaman Go_AND_ID '
#                                          '(9eVNWFMMSrO3Jbo0oWxkFQ) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=9eVNWFMMSrO3Jbo0oWxkFQ&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '20146', 'uniq': '16105'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 0,
#                                   'count': 0,
#                                   'earning': 0,
#                                   'null': 0,
#                                   'revenue': 0}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 9391,
#                                 'offer_id': '5bb1cee5dbb32750cf748856',
#                                 'title': 'Dlab_LINE_Rangers_TW_iOS_WT '
#                                          '(MhGn63PBRs6PVUpq2paDNA) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=MhGn63PBRs6PVUpq2paDNA&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '108179', 'uniq': '101870'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
# ...
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 0,
#                                   'count': 0,
#                                   'earning': 0,
#                                   'null': 0,
#                                   'revenue': 0}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 8569,
#                                 'offer_id': '5badb383dbb3270686398cf8',
#                                 'title': 'Dlab_Hashmatch_JP_iOS_1808 '
#                                          '(SWv_7oL3RRWu3HQ2D9KlPA) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=SWv_7oL3RRWu3HQ2D9KlPA&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '68932', 'uniq': '67482'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 100.5,
#                                       'count': 67,
#                                       'earning': 40.2,
#                                       'null': 0,
#                                       'revenue': 60.3},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 100.5,
#                                   'count': 67,
#                                   'earning': 40.2,
#                                   'null': 0,
#                                   'revenue': 60.3}},
#             'cr': {'confirmed': 0.02,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0.02},
#             'ctr': 0,
#             'epc': 0.0003,
#             'ratio': '1:5469',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 8574,
#                                 'offer_id': '5badd721dbb32708601bb49a',
#                                 'title': 'Dlab_Dragalia Lost_JP_iOS '
#                                          '(pch9d-8yR42wP1th3J5uCQ) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=pch9d-8yR42wP1th3J5uCQ&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '366455', 'uniq': '343180'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 1,
#                                       'count': 1,
#                                       'earning': 0.4,
#                                       'null': 0,
#                                       'revenue': 0.6},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 1,
#                                   'count': 1,
#                                   'earning': 0.4,
#                                   'null': 0,
#                                   'revenue': 0.6}},
#             'cr': {'confirmed': 0.01,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0.01},
#             'ctr': 0,
#             'epc': 0.0001,
#             'ratio': '1:8640',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 3269,
#                                 'offer_id': '5b910eb2dbb3277f05290455',
#                                 'title': 'Dlab_Lenskart_IN_AND_API '
#                                          '(qGQBny5cSNeEx_dz-u1dFw) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=qGQBny5cSNeEx_dz-u1dFw&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '8640', 'uniq': '5627'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 16.1,
#                                       'count': 23,
#                                       'earning': 6.9,
#                                       'null': 0,
#                                       'revenue': 9.2},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 16.1,
#                                   'count': 23,
#                                   'earning': 6.9,
#                                   'null': 0,
#                                   'revenue': 9.2}},
#             'cr': {'confirmed': 0.01,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0.01},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '1:16916',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 6337,
#                                 'offer_id': '5ba39146dbb327920967da4e',
#                                 'title': 'Dlab_Lazada Thailand ios '
#                                          '(uSPL9fV3TR-EMIcgXRGBag) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=uSPL9fV3TR-EMIcgXRGBag&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '389068', 'uniq': '367608'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 358.2,
#                                       'count': 199,
#                                       'earning': 149.25,
#                                       'null': 0,
#                                       'revenue': 208.95},
#                         'declined': {'charge': 0,
#                                      'count': 1,
#                                      'earning': 0,
#                                      'null': 1,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 358.2,
#                                   'count': 200,
#                                   'earning': 149.25,
#                                   'null': 1,
#                                   'revenue': 208.95}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0.0001,
#             'ratio': '1:22149',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 2562,
#                                 'offer_id': '5b8775c63582bf67ca328a73',
#                                 'title': 'API_Dlab_SHOPLIST_iOS '
#                                          '(3Ee9bDeRQDm8ZURd5bP9ag) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=3Ee9bDeRQDm8ZURd5bP9ag&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '4429881', 'uniq': '3993464'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 45.9,
#                                       'count': 51,
#                                       'earning': 20.4,
#                                       'null': 0,
#                                       'revenue': 25.5},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 45.9,
#                                   'count': 51,
#                                   'earning': 20.4,
#                                   'null': 0,
#                                   'revenue': 25.5}},
#             'cr': {'confirmed': 0.01,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0.01},
#             'ctr': 0,
#             'epc': 0.0001,
#             'ratio': '1:12518',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 2743,
#                                 'offer_id': '5b8cede1dbb3273e0e35cf76',
#                                 'title': 'Dlab_Traveloka_VN_iOS '
#                                          '<social_traveloka> '
#                                          '(xQOAzJK9TNyWhGYWHcJK0Q) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=xQOAzJK9TNyWhGYWHcJK0Q&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '638419', 'uniq': '599393'},
#             'views': 0},
#            {'actions': {'confirmed': {'charge': 8.8,
#                                       'count': 8,
#                                       'earning': 3.6,
#                                       'null': 0,
#                                       'revenue': 5.2},
#                         'declined': {'charge': 0,
#                                      'count': 0,
#                                      'earning': 0,
#                                      'null': 0,
#                                      'revenue': 0},
#                         'hold': {'charge': 0,
#                                  'count': 0,
#                                  'earning': 0,
#                                  'null': 0,
#                                  'revenue': 0},
#                         'not_found': {'charge': 0,
#                                       'count': 0,
#                                       'earning': 0,
#                                       'null': 0,
#                                       'revenue': 0},
#                         'pending': {'charge': 0,
#                                     'count': 0,
#                                     'earning': 0,
#                                     'null': 0,
#                                     'revenue': 0},
#                         'total': {'charge': 8.8,
#                                   'count': 8,
#                                   'earning': 3.6,
#                                   'null': 0,
#                                   'revenue': 5.2}},
#             'cr': {'confirmed': 0,
#                    'declined': 0,
#                    'hold': 0,
#                    'not_found': 0,
#                    'pending': 0,
#                    'total': 0},
#             'ctr': 0,
#             'epc': 0,
#             'ratio': '1:33061',
#             'slice': {'offer': {'external_offer_id': None,
#                                 'id': 5134,
#                                 'offer_id': '5b9fa563dbb3274a3f08dd07',
#                                 'title': 'Dlab_Frip_nCPI_KR_iOS_1808 '
#                                          '(nIz5RHNiSl-m-HxJl-DKiQ) (NET-45)',
#                                 'url': 'https://rfrl.pw/xxk?c=nIz5RHNiSl-m-HxJl-DKiQ&pt=03bVNw6&pi={pid}&spi={sub2}&ma={DeviceIds[MAC]}&ia={sub4}&ai={DeviceIds[AndroidID]}&aia={sub4}&ts={ts}&h1={clickid}&cn={sub3}'}},
#             'traffic': {'raw': '264484', 'uniq': '223437'},
#             'views': 0}],
#  'status': 1}

# %%
offers = [
    {
        'id': elem['slice']['offer']['id'],
        'title': elem['slice']['offer']['title'],
        'charge': elem['actions']['total']['charge'],
        'revenue': elem['actions']['total']['revenue'],
        'earning': elem['actions']['total']['earning']
    } for elem in elems
]

pprint(offers)
# Out:
# [{'charge': 6.4,
#   'earning': 2.6,
#   'id': 9413,
#   'revenue': 3.8,
#   'title': 'Dlab_FINAL FANTASY BRAVE EXVIUS_JP_iOS_1805_SM '
#            '(flaJdhVSSIK8KlbWHNHWvA) (NET-45)'},
#  {'charge': 81.6,
#   'earning': 35.7,
#   'id': 3239,
#   'revenue': 45.9,
#   'title': 'Dlab_SSG TV Shopping_KR_And_1805 (Q5CB_5WERqGsneaLgh9foA) '
#            '(NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 2815,
#   'revenue': 0,
#   'title': 'Dlab_LINE BROWN FARM_JP_And (zIAm9J4eTcCHIUDyHe2ohw) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 1715,
#   'revenue': 0,
#   'title': 'Yahoo Partner JP iOS (NET-45) PR12'},
#  {'charge': 2.6,
#   'earning': 1.05,
#   'id': 6335,
#   'revenue': 1.55,
#   'title': 'Dlab_萬王之王_HKMO_And BL (GchoyDhtSjivgUaophtMuA) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 7126,
#   'revenue': 0,
#   'title': 'Dlab_烈火如歌_MY_And (KO7wUhkESkePmMHBcp3m5g) (NET-45)'},
#  {'charge': 2.2,
#   'earning': 0.88,
#   'id': 2445,
#   'revenue': 1.32,
#   'title': 'IDOLiSH7 JP Android (NET-45)'},
#  {'charge': 148.5,
#   'earning': 60.5,
#   'id': 2862,
#   'revenue': 88,
#   'title': 'Dlab_Texas Poker_TW_And (180628 GreenOpen) '
#            '(9Uw594AgTPqDvZ8ylhEPpw) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 5794,
#   'revenue': 0,
#   'title': 'Dlab_Spotify_JP_And_1805_SM (LBaseHWNQamIdpHsWIriow) (NET-45)'},
#  {'charge': 77,
#   'earning': 30.8,
#   'id': 2222,
#   'revenue': 46.2,
#   'title': 'Rakuten Ichiba Cyber JP Android (NET-45)'},
#  {'charge': 3.5,
#   'earning': 1.4,
#   'id': 7389,
#   'revenue': 2.1,
#   'title': 'Dlab_En-musubi_JP_iOS_201804_SM (iOYWwi9LQuC5UTmw1UlNTQ) (NET-45)'},
#  {'charge': 70.4,
#   'earning': 28.8,
#   'id': 3421,
#   'revenue': 41.6,
#   'title': 'Dlab_Live.me_JP_iOS (LGm901SDTBmDjf-7dSHwrQ) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 3238,
#   'revenue': 0,
#   'title': 'Dlab_Tatacliq_IN_And_BL (MmGENSuRQ4y8MNYhiRkBvQ) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 3418,
#   'revenue': 0,
#   'title': 'Dlab_Kotak_CPR_IN_And (XmSpzNROQxSFfaYt49ZvUw) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 3281,
#   'revenue': 0,
#   'title': 'Dlab_Mr. Voonik CPS And_API (XQl_p49tTo6CZXimUcYlWw) (NET-45)'},
#  {'charge': 154,
#   'earning': 63.25,
#   'id': 6640,
#   'revenue': 90.75,
#   'title': 'Dlab_仙劍逍遙遊_TW_And_BL (iIQ_DbOvQXSqofCOzk-u8A) (NET-45)'},
#  {'charge': 620.1,
#   'earning': 262.35,
#   'id': 6182,
#   'revenue': 357.75,
#   'title': 'Dlab_Spotify_JP_iOS_1805_SM (PGAm0IKFSQungcPRpyZOYA) (NET-45)'},
#  {'charge': 12,
#   'earning': 5,
#   'id': 3502,
#   'revenue': 7,
#   'title': 'Dlab_Brandi NCPI_KR_1807_iOS (HxUXtaE7QXO0nmAkeEXQEA) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 5029,
#   'revenue': 0,
#   'title': 'Dlab_Pinjaman Go_AND_ID (9eVNWFMMSrO3Jbo0oWxkFQ) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 9391,
#   'revenue': 0,
#   'title': 'Dlab_LINE_Rangers_TW_iOS_WT (MhGn63PBRs6PVUpq2paDNA) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 7127,
#   'revenue': 0,
#   'title': 'Dlab_烈火如歌_SG_And (hTq1O5trQCaxXR7nwbdFgA) (NET-45)'},
#  {'charge': 8.8,
#   'earning': 3.52,
#   'id': 2448,
#   'revenue': 5.28,
#   'title': 'IDOLiSH7 JP iOS (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 3417,
#   'revenue': 0,
#   'title': 'Dlab_IQOption_CPI_SG_And_WL (iRG-WmdLTGGGyegvQJm4dg) (NET-45)'},
#  {'charge': 179.2,
#   'earning': 72,
#   'id': 2710,
#   'revenue': 107.2,
#   'title': 'Dlab_Mercari_JP_iOS_1808 (XaBmhcIESnqUYz9junxyrg) (NET-45)'},
#  {'charge': 225,
#   'earning': 90,
#   'id': 5588,
#   'revenue': 135,
#   'title': 'Dlab_EnsembleStars_JP_iOS_1709 (SihN7vuMRzuQeB2kkLD8bw) (NET-45)'},
#  {'charge': 30.8,
#   'earning': 12.4,
#   'id': 8624,
#   'revenue': 18.4,
#   'title': 'Dlab_Wild Arms Million Memories_JP_And (U5MrUMX8RwWQt-JdGUPJOg) '
#            '(NET-45)'},
#  {'charge': 18,
#   'earning': 7.2,
#   'id': 4172,
#   'revenue': 10.8,
#   'title': 'Dlab_WhoWatch_JP_iOS_1805_SM (iKVfksaLRA-A4O8JtvBecQ) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 3320,
#   'revenue': 0,
#   'title': 'Dlab_Rakuten Ichiba_Cyber_JP_And_API_0907 (aLZ5iaSxSnGD8vCGFvrgww) '
#            '(NET-45)'},
#  {'charge': 3,
#   'earning': 1.2,
#   'id': 6333,
#   'revenue': 1.8,
#   'title': 'Dlab_萬王之王_HKMO_iOS BL (7SJy2I6cSvKSO8N9J7xTtw) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 6001,
#   'revenue': 0,
#   'title': 'Dlab_Lazada ID iOS SM (hZhWYRQtR_GwLUn9j4lR_A) (NET-45)'},
#  {'charge': 86.12,
#   'earning': 40.52,
#   'id': 3416,
#   'revenue': 45.6,
#   'title': 'Dlab_Zilingo_CPI_ID_And_BL (RAK9LDLdSlaCyqjTrC1TvQ) (NET-45)'},
#  {'charge': 126.1,
#   'earning': 51.65,
#   'id': 5688,
#   'revenue': 74.45,
#   'title': 'Dlab_ZaloPay_VN_iOS_Sep_BL (bKOAlpaIRTGJmwqF1AWwpA) (NET-45)'},
#  {'charge': 4.5,
#   'earning': 1.8,
#   'id': 7977,
#   'revenue': 2.7,
#   'title': 'Dlab_Lotto Rich_KR_And_SM (3nAPScKERJK1Xuia-eonVg) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 7480,
#   'revenue': 0,
#   'title': 'Dlab_連合艦隊_JP_iOS (IFYBPrv8TAm_pDgwI_bTtw) (NET-45)'},
#  {'charge': 2,
#   'earning': 0.8,
#   'id': 8625,
#   'revenue': 1.2,
#   'title': 'Dlab_Wild Arms Million Memories_JP_iOS (luKPSX1BTKOyzusue2WAYA) '
#            '(NET-45)'},
#  {'charge': 67.2,
#   'earning': 28,
#   'id': 5840,
#   'revenue': 39.2,
#   'title': 'Dlab_Lazada MY IOS SM (qRBauRmHSVe1R9ZMflGh-w) (NET-45)'},
#  {'charge': 266,
#   'earning': 106.4,
#   'id': 2153,
#   'revenue': 159.6,
#   'title': 'GRAN BLUE FANTASY iOS JP (NET-45)'},
#  {'charge': 45.6,
#   'earning': 18.6,
#   'id': 5758,
#   'revenue': 27,
#   'title': 'Dlab_萬王之王_TW_iOS_BL (4DnbGZOsQOm_6vzTcALSAQ) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 3500,
#   'revenue': 0,
#   'title': 'Dlab_Captain Tsubasa_Cyber_US_iOS_0911 (FfzredxSRQelXMqD8UbktA) '
#            '(NET-45)'},
#  {'charge': 450,
#   'earning': 180,
#   'id': 2336,
#   'revenue': 270,
#   'title': 'API_Dlab_Happy mail_iOS (TmhmgrxrSsO-3jgyIfWcqg) (NET-45)'},
#  {'charge': 1,
#   'earning': 0.4,
#   'id': 3270,
#   'revenue': 0.6,
#   'title': 'Dlab_DRAGONBALL LEGENDS_KR_iOS (vLiDVkGsRsKU0-5VP_cE8w) (NET-45)'},
#  {'charge': 230.8,
#   'earning': 93.9,
#   'id': 2802,
#   'revenue': 136.9,
#   'title': 'Dlab_老子有錢_TW_And (kCcA-ACQSS6zpLOwQDtqVQ) (NET-45)'},
#  {'charge': 4.2,
#   'earning': 1.8,
#   'id': 2651,
#   'revenue': 2.4,
#   'title': 'Dlab_Tiket.com_CPI_ID_And_BL (3FWof99hR8WNHxa2c69wZw) (NET-45)'},
#  {'charge': 161.2,
#   'earning': 65.9,
#   'id': 3998,
#   'revenue': 95.3,
#   'title': 'Dlab_U.LU_黑暗 Glory_KR_iOS (d9X0XYuWRtKeCmHyPy7zeg) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 2830,
#   'revenue': 0,
#   'title': 'Dlab_DRAGONBALL LEGENDS_HK_And (d9tb2GEERu-xoZm6PtHy4Q) (NET-45)'},
#  {'charge': 20,
#   'earning': 8,
#   'id': 4163,
#   'revenue': 12,
#   'title': 'Dlab_LINEAGE2 REVOLUTION_JP_iOS_1809_SM Device ID required '
#            '(yqvdc89WRjmegCyu9xryMw) (NET-45)'},
#  {'charge': 183.6,
#   'earning': 74.8,
#   'id': 3344,
#   'revenue': 108.8,
#   'title': 'Dlab_BonusWinner宅神爺_And_TW_BL (22WPZqWvRO2j6-HZ2oZpWQ) (NET-45)'},
#  {'charge': 9,
#   'earning': 3.6,
#   'id': 8570,
#   'revenue': 5.4,
#   'title': 'Dlab_TSUBAKI_JP_iOS (URDpWQrdQ_2aeEnBk5PCmg) (NET-45)'},
#  {'charge': 39.9,
#   'earning': 17.1,
#   'id': 2756,
#   'revenue': 22.8,
#   'title': 'Dlab_Agoda_IN_iOS_1806 (87R9Rpg3SU6xbbreEFngow) (NET-45)'},
#  {'charge': 2,
#   'earning': 0.8,
#   'id': 2740,
#   'revenue': 1.2,
#   'title': 'Dlab_KOF_JP_1808_iOS (S3rR5P1OTzmGHMnPjZOf3A) (NET-45)'},
#  {'charge': 260,
#   'earning': 104,
#   'id': 3200,
#   'revenue': 156,
#   'title': 'Dlab_Bytedance (Tiktok)_CPI_JP_And (ZOLQzme8T_iCo3bmzcN8dw) '
#            '(NET-45)'},
#  {'charge': 40.8,
#   'earning': 17,
#   'id': 7975,
#   'revenue': 23.8,
#   'title': 'Dlab_musou zan_201809_JP_And (r0gtFFk-QT-3Jf4tozvk2A) (NET-45)'},
#  {'charge': 9.6,
#   'earning': 4,
#   'id': 8782,
#   'revenue': 5.6,
#   'title': 'Dlab_DRAGONBALL LEGENDS_KR_And (qC1d0DaqT_ejAJqzV6IIHQ) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 2739,
#   'revenue': 0,
#   'title': 'Dlab_KOF_JP_1808_And Device ID required (QSSLaPWLQqOY-wO3-kv-rQ) '
#            '(NET-45)'},
#  {'charge': 5.5,
#   'earning': 2.2,
#   'id': 5961,
#   'revenue': 3.3,
#   'title': 'Dlab_Neds_CPI Opt CPA_AU_BL (wBhN6ZW2QcyGhqhpkjtr5Q) (NET-45)'},
#  {'charge': 11.5,
#   'earning': 4.75,
#   'id': 2804,
#   'revenue': 6.75,
#   'title': 'Dlab_金好運_TW_And_BL (QUGgUZk4SqWTynpBBWll_A) (NET-45)'},
#  {'charge': 217,
#   'earning': 86.8,
#   'id': 2831,
#   'revenue': 130.2,
#   'title': 'Dlab_Gamesofa_LuxyPoker_ID_And_BL (1TSqvBzWT8ay0MRV_IjHBw) '
#            '(NET-45)'},
#  {'charge': 1.6,
#   'earning': 0.7,
#   'id': 2982,
#   'revenue': 0.9,
#   'title': 'Dlab_Pmang Matgo_And_KR_1807 (Yo0LAggcSG6raBvxIxqNmg) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 2757,
#   'revenue': 0,
#   'title': 'Dlab_Agoda_UK_iOS_1806_v5Tn (yJHOOVTERXS7HpQrTRkvaw) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 9381,
#   'revenue': 0,
#   'title': 'Dlab_Brandi NCPI_KR_1807_And (egLoYCPYRCO7BmPVS89trw) (NET-45)'},
#  {'charge': 5,
#   'earning': 2,
#   'id': 4162,
#   'revenue': 3,
#   'title': 'Dlab_LINEAGE2 REVOLUTION_JP_And_1809_SM (ZSwypV2mSsynkCNp3eXJ2A) '
#            '(NET-45)'},
#  {'charge': 8,
#   'earning': 3.2,
#   'id': 8783,
#   'revenue': 4.8,
#   'title': 'Dlab_Lovestruck_HK_And (Nt6xgU1_SaWb5eGTJBHu8A) (NET-45)'},
#  {'charge': 37.1,
#   'earning': 15.9,
#   'id': 5687,
#   'revenue': 21.2,
#   'title': 'Dlab_ZaloPay_VN_And_Sep (9Wb2FUg0SOaEUlUY8MuVAQ) (NET-45)'},
#  {'charge': 142.8,
#   'earning': 58.65,
#   'id': 4935,
#   'revenue': 84.15,
#   'title': 'Dlab_烈火如歌_TW_And_BL (FhSx0_5ET3KsRR4aLb426g) (NET-45)'},
#  {'charge': 147,
#   'earning': 58.8,
#   'id': 8575,
#   'revenue': 88.2,
#   'title': 'Dlab_Dragalia Lost_JP_And (zjJlDyRsSiqxceFfcocOIw) (NET-45)'},
#  {'charge': 220,
#   'earning': 88,
#   'id': 2676,
#   'revenue': 132,
#   'title': 'API_Dlab_Happy mail_iOS (AEh9m0UMQzaX3DIjUhq65w) (NET-45)'},
#  {'charge': 4.5,
#   'earning': 2,
#   'id': 9382,
#   'revenue': 2.5,
#   'title': 'Dlab_Lazada PH iOS (GB2rPXG0S9KP8xuGg_dPvg) (NET-45)'},
#  {'charge': 5,
#   'earning': 2,
#   'id': 2963,
#   'revenue': 3,
#   'title': 'Dlab_PRINCESS CONNECT_JP_And_1802 (PbUJ-Nf1SGOsnKWO3EARMA) '
#            '(NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 7129,
#   'revenue': 0,
#   'title': 'Dlab_烈火如歌_MY_iOS (upgKAHBTRXK8h_fxuaZa2w) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 2832,
#   'revenue': 0,
#   'title': 'Dlab_DRAGONBALL LEGENDS_HK_iOS (G0jHs4-BSf-XjwathIB_2Q) (NET-45)'},
#  {'charge': 6.6,
#   'earning': 2.7,
#   'id': 3268,
#   'revenue': 3.9,
#   'title': 'Dlab_Frip_nCPI_KR_And_1808 (T_pDgiMvQRSI5BnSDlZisg) (NET-45)'},
#  {'charge': 12,
#   'earning': 4.8,
#   'id': 4705,
#   'revenue': 7.2,
#   'title': 'Dlab_Captain Tsubasa_Cyber_JP_iOS_BL (KxxxNBZfStqFbP9fDubhAA) '
#            '(NET-45)'},
#  {'charge': 9.8,
#   'earning': 4.2,
#   'id': 8389,
#   'revenue': 5.6,
#   'title': 'Dlab_Lazada VN IOS (YqHMIcTERwGkCLp3dAKlmA) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 6336,
#   'revenue': 0,
#   'title': 'Dlab_Lazada ID And (bux_lxjLSmuyLbwe5UwziQ) (NET-45)'},
#  {'charge': 351.9,
#   'earning': 145.35,
#   'id': 5084,
#   'revenue': 206.55,
#   'title': 'Dlab_烈火如歌_TW_iOS (f9Q4gQOYQzCq91wy8I4u0A) (NET-45)'},
#  {'charge': 16,
#   'earning': 6.5,
#   'id': 2730,
#   'revenue': 9.5,
#   'title': 'Dlab_神來也麻將_TW_iOS (自選秒數篇) (IuUJrfD1Sy6lh8KtxNXL6Q) (NET-45)'},
#  {'charge': 4,
#   'earning': 1.6,
#   'id': 7128,
#   'revenue': 2.4,
#   'title': 'Dlab_烈火如歌_SG_iOS_BL (qRdJPzT0QzCUq7ANGF38tA) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 3494,
#   'revenue': 0,
#   'title': 'Dlab_Agoda_Android_KR (Xc1Lz1lvT0G4lor0XPIgYw) (NET-45)'},
#  {'charge': 0,
#   'earning': 0,
#   'id': 8569,
#   'revenue': 0,
#   'title': 'Dlab_Hashmatch_JP_iOS_1808 (SWv_7oL3RRWu3HQ2D9KlPA) (NET-45)'},
#  {'charge': 100.5,
#   'earning': 40.2,
#   'id': 8574,
#   'revenue': 60.3,
#   'title': 'Dlab_Dragalia Lost_JP_iOS (pch9d-8yR42wP1th3J5uCQ) (NET-45)'},
#  {'charge': 1,
#   'earning': 0.4,
#   'id': 3269,
#   'revenue': 0.6,
#   'title': 'Dlab_Lenskart_IN_AND_API (qGQBny5cSNeEx_dz-u1dFw) (NET-45)'},
#  {'charge': 16.1,
#   'earning': 6.9,
#   'id': 6337,
#   'revenue': 9.2,
#   'title': 'Dlab_Lazada Thailand ios (uSPL9fV3TR-EMIcgXRGBag) (NET-45)'},
#  {'charge': 358.2,
#   'earning': 149.25,
#   'id': 2562,
#   'revenue': 208.95,
#   'title': 'API_Dlab_SHOPLIST_iOS (3Ee9bDeRQDm8ZURd5bP9ag) (NET-45)'},
#  {'charge': 45.9,
#   'earning': 20.4,
#   'id': 2743,
#   'revenue': 25.5,
#   'title': 'Dlab_Traveloka_VN_iOS <social_traveloka> (xQOAzJK9TNyWhGYWHcJK0Q) '
#            '(NET-45)'},
#  {'charge': 8.8,
#   'earning': 3.6,
#   'id': 5134,
#   'revenue': 5.2,
#   'title': 'Dlab_Frip_nCPI_KR_iOS_1808 (nIz5RHNiSl-m-HxJl-DKiQ) (NET-45)'}]
